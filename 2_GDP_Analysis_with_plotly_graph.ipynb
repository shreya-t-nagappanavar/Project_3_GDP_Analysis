# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-t-nagappanavar/Project_3_GDP_Analysis/blob/main/2_GDP_Analysis_with_plotly_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/gdp.csv')

# %%
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
df['Country Name'].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
df['Country Name'].nunique()
# Out:
# 256

# %%
c = 0
for i in df['Country Name']:
  if i == "India":
    c += 1
print(c)
# Out:
# 57

# %%
len(df['Country Name'])
# Out:
# 11507

# %%
df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# Year            0
# Value           0
# dtype: int64

# %% [markdown]
# # Check Description of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11507 entries, 0 to 11506
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  11507 non-null  object
#  1   Country Code  11507 non-null  object
#  2   Year          11507 non-null  int64
#  3   Value         11507 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 359.7+ KB

# %%
df['Country Name'].describe()
# Out:
# count                    11507
# unique                     256
# top       Hong Kong SAR, China
# freq                        57
# Name: Country Name, dtype: object

# %%
df['Country Code'].describe()
# Out:
# count     11507
# unique      256
# top         HKG
# freq         57
# Name: Country Code, dtype: object

# %%
df['Year'].describe()
# Out:
# count    11507.000000
# mean      1991.265230
# std         15.886648
# min       1960.000000
# 25%       1978.000000
# 50%       1993.000000
# 75%       2005.000000
# max       2016.000000
# Name: Year, dtype: float64

# %% [markdown]
# # Analysing Arab World

# %%
df_pr = df[df['Country Name'] == 'Arab World']

# %%
df_pr
# Out:
#    Country Name Country Code  Year         Value
# 0    Arab World          ARB  1968  2.576068e+10
# 1    Arab World          ARB  1969  2.843420e+10
# 2    Arab World          ARB  1970  3.138550e+10
# 3    Arab World          ARB  1971  3.642691e+10
# 4    Arab World          ARB  1972  4.331606e+10
# 5    Arab World          ARB  1973  5.501839e+10
# 6    Arab World          ARB  1974  1.051458e+11
# 7    Arab World          ARB  1975  1.163370e+11
# 8    Arab World          ARB  1976  1.448462e+11
# 9    Arab World          ARB  1977  1.673083e+11
# 10   Arab World          ARB  1978  1.835555e+11
# 11   Arab World          ARB  1979  2.486462e+11
# 12   Arab World          ARB  1980  3.381775e+11
# 13   Arab World          ARB  1981  3.485928e+11
# 14   Arab World          ARB  1982  3.243288e+11
# 15   Arab World          ARB  1983  3.039625e+11
# 16   Arab World          ARB  1984  3.079408e+11
# 17   Arab World          ARB  1985  3.038936e+11
# ...

# %%
df_pr.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df_pr.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (15,6), grid = True, legend = False) #legend used to remove (-value) inside the graph
#grid used to get square boxes inside
# Out:
# <Axes: xlabel='Year'>

# %%
df_pr.plot(kind = 'line',
           x = 'Year', xlabel = 'Years',
           y = 'Value', ylabel = 'GDP',
           figsize = (15,6),
           grid = True,
           legend = False,
           title = 'Arab year growth analysis  with values')
# Out:
# <Axes: title={'center': 'Arab year growth analysis  with values'}, xlabel='Years', ylabel='GDP'>

# %% [markdown]
# #  Analysing India

# %%
df_in = df[df['Country Name'] == 'India']

# %%
df_in.head()
# Out:
#      Country Name Country Code  Year         Value
# 6074        India          IND  1960  3.653593e+10
# 6075        India          IND  1961  3.870910e+10
# 6076        India          IND  1962  4.159907e+10
# 6077        India          IND  1963  4.777600e+10
# 6078        India          IND  1964  5.572687e+10

# %%
df_in.plot(kind = 'line',
           x = 'Year', xlabel = 'Years',
           y = 'Value', ylabel = 'GDP',
           figsize = (15,6),
           grid = True,
           legend = False,
           title = 'India growth analysis  with values')
# Out:
# <Axes: title={'center': 'India growth analysis  with values'}, xlabel='Years', ylabel='GDP'>

# %% [markdown]
# # Analysis with value column(Using Arab dataset)

# %%
df_pr['Year'].head()
# Out:
# 0    1968
# 1    1969
# 2    1970
# 3    1971
# 4    1972
# Name: Year, dtype: int64

# %%
df_pr.values
# Out:
# array([['Arab World', 'ARB', 1968, 25760683041.0857],
#        ['Arab World', 'ARB', 1969, 28434203615.4829],
#        ['Arab World', 'ARB', 1970, 31385499664.0672],
#        ['Arab World', 'ARB', 1971, 36426909888.3928],
#        ['Arab World', 'ARB', 1972, 43316056615.4562],
#        ['Arab World', 'ARB', 1973, 55018394945.5825],
#        ['Arab World', 'ARB', 1974, 105145803084.377],
#        ['Arab World', 'ARB', 1975, 116337021938.341],
#        ['Arab World', 'ARB', 1976, 144846175400.488],
#        ['Arab World', 'ARB', 1977, 167308327683.593],
#        ['Arab World', 'ARB', 1978, 183555544342.189],
#        ['Arab World', 'ARB', 1979, 248646206367.003],
#        ['Arab World', 'ARB', 1980, 338177454717.54],
#        ['Arab World', 'ARB', 1981, 348592795413.116],
#        ['Arab World', 'ARB', 1982, 324328753765.3],
#        ['Arab World', 'ARB', 1983, 303962539723.08],
#        ['Arab World', 'ARB', 1984, 307940771858.542],
# ...

# %%
data = df_pr.values                        #every year growth analysis
for i in range(1,len(data)):
  print(data[i-1],data[i])
# Out:
# ['Arab World' 'ARB' 1968 25760683041.0857] ['Arab World' 'ARB' 1969 28434203615.4829]
# ['Arab World' 'ARB' 1969 28434203615.4829] ['Arab World' 'ARB' 1970 31385499664.0672]
# ['Arab World' 'ARB' 1970 31385499664.0672] ['Arab World' 'ARB' 1971 36426909888.3928]
# ['Arab World' 'ARB' 1971 36426909888.3928] ['Arab World' 'ARB' 1972 43316056615.4562]
# ['Arab World' 'ARB' 1972 43316056615.4562] ['Arab World' 'ARB' 1973 55018394945.5825]
# ['Arab World' 'ARB' 1973 55018394945.5825] ['Arab World' 'ARB' 1974 105145803084.377]
# ['Arab World' 'ARB' 1974 105145803084.377] ['Arab World' 'ARB' 1975 116337021938.341]
# ['Arab World' 'ARB' 1975 116337021938.341] ['Arab World' 'ARB' 1976 144846175400.488]
# ['Arab World' 'ARB' 1976 144846175400.488] ['Arab World' 'ARB' 1977 167308327683.593]
# ['Arab World' 'ARB' 1977 167308327683.593] ['Arab World' 'ARB' 1978 183555544342.189]
# ['Arab World' 'ARB' 1978 183555544342.189] ['Arab World' 'ARB' 1979 248646206367.003]
# ...

# %%
data = df_pr.values
for i in range(1,len(data)):
  prev = data[i-1][3]
  cur = data[i][3]
  print(data[i][2]," : ",round(((cur - prev)/prev)*100,2))
# Out:
# 1969  :  10.38
# 1970  :  10.38
# 1971  :  16.06
# 1972  :  18.91
# 1973  :  27.02
# 1974  :  91.11
# 1975  :  10.64
# 1976  :  24.51
# 1977  :  15.51
# 1978  :  9.71
# 1979  :  35.46
# 1980  :  36.01
# 1981  :  3.08
# 1982  :  -6.96
# 1983  :  -6.28
# 1984  :  1.31
# 1985  :  -1.31
# 1986  :  -4.89
# 1987  :  8.18
# 1988  :  -1.66
# 1989  :  4.82
# 1990  :  38.64
# 1991  :  -1.59
# 1992  :  7.14
# 1993  :  1.14
# 1994  :  2.31
# 1995  :  7.43
# 1996  :  10.4
# 1997  :  6.06
# 1998  :  -3.55
# 1999  :  8.85
# 2000  :  14.15
# 2001  :  -1.6
# 2002  :  0.8
# 2003  :  12.9
# 2004  :  17.1
# 2005  :  22.91
# 2006  :  18.52
# 2007  :  16.63
# 2008  :  26.9
# 2009  :  -13.58
# 2010  :  17.48
# 2011  :  18.58
# 2012  :  9.58
# 2013  :  3.59
# 2014  :  2.36
# 2015  :  -11.81
# 2016  :  -2.29

# %%
data = df_pr.values

gdp_change = [0]

for i in range(1,len(data)):

  prev = data[i-1][3]
  cur = data[i][3]
  gdp_change.append(round(((cur - prev)/prev)*100,2))

# %%
gdp_change
# Out:
# [0,
#  10.38,
#  10.38,
#  16.06,
#  18.91,
#  27.02,
#  91.11,
#  10.64,
#  24.51,
#  15.51,
#  9.71,
#  35.46,
#  36.01,
#  3.08,
#  -6.96,
#  -6.28,
#  1.31,
#  -1.31,
#  -4.89,
#  8.18,
#  -1.66,
#  4.82,
#  38.64,
#  -1.59,
#  7.14,
#  1.14,
#  2.31,
#  7.43,
#  10.4,
#  6.06,
#  -3.55,
#  8.85,
#  14.15,
#  -1.6,
#  0.8,
#  12.9,
#  17.1,
#  22.91,
#  18.52,
#  16.63,
#  26.9,
#  -13.58,
#  17.48,
#  18.58,
#  9.58,
#  3.59,
#  2.36,
#  -11.81,
#  -2.29]

# %%
df_pr['gdp_changes'] = gdp_change
# Out:
# <ipython-input-32-46fc72448240>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pr.head(5)
# Out:
#   Country Name Country Code  Year         Value  gdp_changes
# 0   Arab World          ARB  1968  2.576068e+10         0.00
# 1   Arab World          ARB  1969  2.843420e+10        10.38
# 2   Arab World          ARB  1970  3.138550e+10        10.38
# 3   Arab World          ARB  1971  3.642691e+10        16.06
# 4   Arab World          ARB  1972  4.331606e+10        18.91

# %%
df_pr.plot(kind = 'bar',figsize= (6,6),color = 'black', legend = True, grid = True)
# Out:
# <Axes: >

# %%
df_pr.plot(kind = 'line',figsize= (6,6),color = 'green', legend = True, grid = True)
# Out:
# <Axes: >

# %% [markdown]
# # Finding GDP Growth of a country

# %%
df_pr = df[df['Country Name'] == 'Arab World']

data = df_pr.values

gdp_change = [0]

for i in range(1,len(data)):

  prev = data[i-1][3]
  cur = data[i][3]
  gdp_change.append(round(((cur - prev)/prev)*100,2))
df_pr = df_pr.assign(gdp_changes = gdp_change)

# %% [markdown]
# # Finding GDP Growth of every country

# %%
final_data = []
for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]

  data = df_pr.values

  gdp_change = [0]

  for i in range(1,len(data)):

    prev = data[i-1][3]
    cur = data[i][3]
    gdp_change.append(round(((cur - prev)/prev)*100,2))
  df_pr = df_pr.assign(gdp_changes = gdp_change)
  final_data.append(df_pr)

# %%
final_data
# Out:
# [   Country Name Country Code  Year         Value  gdp_changes
#  0    Arab World          ARB  1968  2.576068e+10         0.00
#  1    Arab World          ARB  1969  2.843420e+10        10.38
#  2    Arab World          ARB  1970  3.138550e+10        10.38
#  3    Arab World          ARB  1971  3.642691e+10        16.06
#  4    Arab World          ARB  1972  4.331606e+10        18.91
#  5    Arab World          ARB  1973  5.501839e+10        27.02
#  6    Arab World          ARB  1974  1.051458e+11        91.11
#  7    Arab World          ARB  1975  1.163370e+11        10.64
#  8    Arab World          ARB  1976  1.448462e+11        24.51
#  9    Arab World          ARB  1977  1.673083e+11        15.51
#  10   Arab World          ARB  1978  1.835555e+11         9.71
#  11   Arab World          ARB  1979  2.486462e+11        35.46
#  12   Arab World          ARB  1980  3.381775e+11        36.01
#  13   Arab World          ARB  1981  3.485928e+11         3.08
# ...

# %%
df = pd.concat(final_data, axis = 0)

# %%
df
# Out:
#       Country Name Country Code  Year         Value  gdp_changes
# 0       Arab World          ARB  1968  2.576068e+10         0.00
# 1       Arab World          ARB  1969  2.843420e+10        10.38
# 2       Arab World          ARB  1970  3.138550e+10        10.38
# 3       Arab World          ARB  1971  3.642691e+10        16.06
# 4       Arab World          ARB  1972  4.331606e+10        18.91
# ...            ...          ...   ...           ...          ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10        17.72
# 11503     Zimbabwe          ZWE  2013  1.545177e+10         8.49
# 11504     Zimbabwe          ZWE  2014  1.589105e+10         2.84
# 11505     Zimbabwe          ZWE  2015  1.630467e+10         2.60
# 11506     Zimbabwe          ZWE  2016  1.661996e+10         1.93
#
# [11507 rows x 5 columns]

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value  gdp_changes
# 0   Arab World          ARB  1968  2.576068e+10         0.00
# 1   Arab World          ARB  1969  2.843420e+10        10.38
# 2   Arab World          ARB  1970  3.138550e+10        10.38
# 3   Arab World          ARB  1971  3.642691e+10        16.06
# 4   Arab World          ARB  1972  4.331606e+10        18.91

# %%
df.groupby('Country Name').mean('gdp_changes')
# Out:
#                       Year         Value  gdp_changes
# Country Name
# Afghanistan         1986.5  6.226405e+09    11.204737
# Albania             2000.0  6.011364e+09     8.232121
# Algeria             1988.0  6.147467e+10     8.415614
# American Samoa      2009.0  5.805333e+08     1.937333
# Andorra             1993.0  1.468489e+09     8.817660
# ...                    ...           ...          ...
# West Bank and Gaza  2005.0  6.648426e+09     7.273913
# World               1988.0  2.609594e+13     7.454386
# Yemen, Rep.         2003.0  1.746357e+10     7.137037
# Zambia              1988.0  6.329683e+09     7.603684
# Zimbabwe            1988.0  6.284678e+09     6.032982
#
# [256 rows x 3 columns]

# %%
df.groupby('Country Name').mean()['gdp_changes'].sort_values()
# Out:
# <ipython-input-43-548b55f898b7>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Country Name
# South Sudan                  -3.166250
# Northern Mariana Islands      0.338667
# American Samoa                1.937333
# San Marino                    2.148333
# Barbados                      3.109259
#                                ...
# Oman                         17.681154
# Iraq                         18.075854
# Nauru                        20.650000
# Equatorial Guinea            22.312453
# Cayman Islands              108.380000
# Name: gdp_changes, Length: 256, dtype: float64

# %%
df.groupby('Country Name').mean()['gdp_changes'].sort_values(ascending = False)
# Out:
# <ipython-input-44-a2b367ea5de3>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Country Name
# Cayman Islands              108.380000
# Equatorial Guinea            22.312453
# Nauru                        20.650000
# Iraq                         18.075854
# Oman                         17.681154
#                                ...
# Barbados                      3.109259
# San Marino                    2.148333
# American Samoa                1.937333
# Northern Mariana Islands      0.338667
# South Sudan                  -3.166250
# Name: gdp_changes, Length: 256, dtype: float64

# %%
df.groupby('Country Name').mean()['gdp_changes'].sort_values(ascending = False).head(5)
# Out:
# <ipython-input-45-5caaacdeaf6a>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Country Name
# Cayman Islands       108.380000
# Equatorial Guinea     22.312453
# Nauru                 20.650000
# Iraq                  18.075854
# Oman                  17.681154
# Name: gdp_changes, dtype: float64

# %%
df.groupby('Country Name').mean()['gdp_changes'].sort_values(ascending = False).tail(5)
# Out:
# <ipython-input-46-fb892c204ca0>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Country Name
# Barbados                    3.109259
# San Marino                  2.148333
# American Samoa              1.937333
# Northern Mariana Islands    0.338667
# South Sudan                -3.166250
# Name: gdp_changes, dtype: float64

# %% [markdown]
# # Analysing with plotly graph

# %%
import plotly.express as px
import plotly.offline as pyo

# %%
df_pr = df[df['Country Name'] == 'World']

# %%
df_pr
# Out:
#      Country Name Country Code  Year         Value  gdp_changes
# 2249        World          WLD  1960  1.366678e+12         0.00
# 2250        World          WLD  1961  1.421788e+12         4.03
# 2251        World          WLD  1962  1.526955e+12         7.40
# 2252        World          WLD  1963  1.643752e+12         7.65
# 2253        World          WLD  1964  1.800796e+12         9.55
# 2254        World          WLD  1965  1.961780e+12         8.94
# 2255        World          WLD  1966  2.128450e+12         8.50
# 2256        World          WLD  1967  2.264600e+12         6.40
# 2257        World          WLD  1968  2.443224e+12         7.89
# 2258        World          WLD  1969  2.690798e+12        10.13
# 2259        World          WLD  1970  2.957800e+12         9.92
# 2260        World          WLD  1971  3.266907e+12        10.45
# 2261        World          WLD  1972  3.767674e+12        15.33
# 2262        World          WLD  1973  4.591346e+12        21.86
# ...

# %%
fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'World GDP Analysis')

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pr = df[df['Country Name'] == 'India']
fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'India GDP Analysis')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pr = df[df['Country Name'] == 'India']
fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'India GDP Analysis',range_y = [0, 20000000000000])
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pyo.plot(fig, filename = 'India GDP.html')
# Out:
# 'India GDP.html'

# %%
pd.read_html('/content/India GDP.html')

# %% [markdown]
# # GDP Analysis plotting graphs in Bulk
# (GDP of each country)

# %%
import os

# %%
df['Country Name'].nunique()
# Out:
# 256

# %%
os.mkdir('GDP Individuals')
for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]
  fig = px.line(df_pr, x = 'Year', y = 'Value', title = country_name + 'GDP Analysis')
  pyo.plot(fig , filename = 'GDP Individual/' + country_name +'.html',auto_open = False)

# %% [markdown]
# GDP of each country WRT 80T

# %%
os.mkdir('GDP Individuals WRT World')
for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]
  fig = px.line(df_pr, x = 'Year', y = 'Value', title = country_name + 'GDP Analysis',range_y = (0,8000000000000))
  pyo.plot(fig , filename = 'GDP Individual WRT World/' + country_name +'.html',auto_open = False)
