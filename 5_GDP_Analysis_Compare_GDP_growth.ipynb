# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-t-nagappanavar/Project_3_GDP_Analysis/blob/main/5_GDP_Analysis_Compare_GDP_growth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.offline as pyo # for html file

# %%
df = pd.read_csv('/content/sample_data/gdp.csv')

# %%
final_data = []
for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]

  data = df_pr.values

  gdp_change = [0]

  for i in range(1,len(data)):

    prev = data[i-1][3]
    cur = data[i][3]
    gdp_change.append(round(((cur - prev)/prev)*100,2))
  df_pr = df_pr.assign(gdp_changes = gdp_change)
  final_data.append(df_pr)
df = pd.concat(final_data, axis = 0)

# %%
c1 = df[df['Country Name'] == 'Arab World']
c2 = df[df['Country Name'] == 'China']
df_pr = pd.concat([c1,c2], axis = 0)
fig = px.line(df_pr,x = 'Year', y = 'Value', color = ('Country Name'), title = 'Analysis between China and Arab World')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c1 = df[df['Country Name'] == 'Arab World']
c2 = df[df['Country Name'] == 'China']
df_pr = pd.concat([c1,c2], axis = 0)
fig = px.line(df_pr,x = 'Year', y = 'Value', color = ('Country Name'), title = 'Analysis between China and Arab World')
fig

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value  gdp_changes
# 0   Arab World          ARB  1968  2.576068e+10         0.00
# 1   Arab World          ARB  1969  2.843420e+10        10.38
# 2   Arab World          ARB  1970  3.138550e+10        10.38
# 3   Arab World          ARB  1971  3.642691e+10        16.06
# 4   Arab World          ARB  1972  4.331606e+10        18.91

# %%
c1 = df[df['Country Name'] == 'Arab World']
c2 = df[df['Country Name'] == 'China']
df_pr = pd.concat([c1,c2], axis = 0)
fig = px.line(df_pr,x = 'Year', y = 'gdp_changes', color = ('Country Name'), title = 'Analysis GDP between China and Arab World')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c1 = df[df['Country Name'] == 'World']
c2 = df[df['Country Name'] == 'China']
df_pr = pd.concat([c1,c2], axis = 0)
fig = px.line(df_pr,x = 'Year', y = 'gdp_changes', color = ('Country Name'), title = 'Analysis GDP between China and World')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c1 = df[df['Country Name'] == 'Italy']
c1 = df[df['Country Name'] == 'Japan']
df_pr = pd.concat([c1,c2],axis = 0)
fig = px.line(df_pr, y = 'gdp_changes',x = 'Year', title = 'Analysis between Japan and Italy',color = 'Country Name')

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Comparison of all countries with GDP growth

# %%
fig = px.line(df, y = 'gdp_changes',x = 'Year', title = 'Analysis between Japan and Italy',color = 'Country Name')

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
